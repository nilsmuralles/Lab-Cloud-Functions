# %% [markdown]
# # Prototipo API de Google Maps en Jupyter Notebook

# %%
import requests
import os
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.environ.get("MAPS_KEY")
url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"
params = {
        "input": "Aeropuerto Internacional La Aurora",
        "inputtype": "textquery",
        "fields": "place_id,name,geometry,formatted_address",
        "key": API_KEY
        }
response = requests.get(url, params=params)

data = response.json()
print(data)
# Out:
# {'candidates': [{'formatted_address': 'Dirección, 9a Avenida 14-75, Cdad. de Guatemala 01013, Guatemala', 'geometry': {'location': {'lat': 14.5879704, 'lng': -90.5306907}, 'viewport': {'northeast': {'lat': 14.58933307989272, 'lng': -90.52938412010728}, 'southwest': {'lat': 14.58663342010728, 'lng': -90.53208377989273}}}, 'name': 'Internationale luchthaven La Aurora', 'place_id': 'ChIJZT6iGF-hiYURyk4trrH52ag'}], 'status': 'OK'}
